# %% [markdown]
# 当你做运动时，你会感到更虚弱，但你实际上正在变强壮。
#
# 当你在学新东西时，你觉得自己很笨，但你实际在变得更加聪明。
#
# 所以，当你在变好时，你一定会先变得脆弱，而这个脆弱的时刻，其实是一个非常重要的进步的时刻！

# %%
# ReID（Person Re-identification，行人重识别）
# 目标是在非重叠摄像头视角下，从大量行人中精准匹配出 “同一人”，解决跨摄像头场景下的 “人是谁、人去哪” 的身份关联问题
# https://v.douyin.com/blvI67UFQuw/

# %%
# Python + YOLOv8 + SuperVision 实现交通监控与车辆自动测速系统
# https://v.douyin.com/0oqIV3_AHa4/
